# %%
#standard quantum teleportation by using Bell-state 
import numpy as np
from qiskit import *
import matplotlib.pyplot as plt
from math import pi
from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister, execute
from qiskit.tools.visualization import circuit_drawer
from qiskit.quantum_info import state_fidelity
from qiskit import BasicAer

from qiskit.tools.visualization import plot_histogram
from qiskit import Aer
from qiskit.tools.visualization import plot_histogram
from qiskit.providers.aer import QasmSimulator

# %matplotlib inline

# %%
#the measurement of original state
q = QuantumRegister(1, 'q')
c = ClassicalRegister(1,'c')
qc= QuantumCircuit(q,c)
qc.h(q[0])
qc.t(q[0])
qc.h(q[0])
qc.s(q[0])
qc.measure(q,c)
qc.draw(output='mpl')

# %%
#simulation result 
simulator = Aer.get_backend('qasm_simulator')
result = execute(qc, simulator).result()
counts = result.get_counts(qc)
plot_histogram(counts, title='final state')

# %%
q = QuantumRegister(3, 'q')
c = ClassicalRegister(3,'c')
qc= QuantumCircuit(q,c)
qc.h(q[0])
qc.t(q[0])
qc.h(q[0])
qc.s(q[0])
qc.h(q[1])
qc.cx(q[1],q[2])
qc.barrier(q)
qc.cx(q[0],q[1])
qc.h(q[0])
qc.barrier(q)
qc.cx(q[1],q[2])
qc.h(q[2])
qc.cx(q[0],q[2])
qc.h(q[2])
qc.barrier(q)
#qc.measure(q,c)
style = {'backgroundcolor': 'lightblue'}
qc.draw(output='mpl',style=style)

# %%
backend = BasicAer.get_backend('unitary_simulator')
job = execute(qc, backend)
job.result().get_unitary(qc, decimals=3)
# Out:
# array([[ 0.427+0.177j,  0.073-0.177j,  0.427+0.177j,  0.073-0.177j,
#          0.177+0.073j, -0.177+0.427j, -0.177-0.073j,  0.177-0.427j],
#        [ 0.427+0.177j,  0.073-0.177j,  0.427+0.177j,  0.073-0.177j,
#         -0.177-0.073j,  0.177-0.427j,  0.177+0.073j, -0.177+0.427j],
#        [ 0.427+0.177j,  0.073-0.177j, -0.427-0.177j, -0.073+0.177j,
#          0.177+0.073j, -0.177+0.427j,  0.177+0.073j, -0.177+0.427j],
#        [ 0.427+0.177j,  0.073-0.177j, -0.427-0.177j, -0.073+0.177j,
#         -0.177-0.073j,  0.177-0.427j, -0.177-0.073j,  0.177-0.427j],
#        [ 0.177+0.073j, -0.177+0.427j, -0.177-0.073j,  0.177-0.427j,
#          0.427+0.177j,  0.073-0.177j,  0.427+0.177j,  0.073-0.177j],
#        [ 0.177+0.073j, -0.177+0.427j, -0.177-0.073j,  0.177-0.427j,
#         -0.427-0.177j, -0.073+0.177j, -0.427-0.177j, -0.073+0.177j],
#        [ 0.177+0.073j, -0.177+0.427j,  0.177+0.073j, -0.177+0.427j,
#          0.427+0.177j,  0.073-0.177j, -0.427-0.177j, -0.073+0.177j],
#        [ 0.177+0.073j, -0.177+0.427j,  0.177+0.073j, -0.177+0.427j,
#         -0.427-0.177j, -0.073+0.177j,  0.427+0.177j,  0.073-0.177j]])

# %%
qc.measure(q,c)
style = {'backgroundcolor': 'lightblue'}
qc.draw(output='mpl',style=style)

# %%
simulator = Aer.get_backend('qasm_simulator')

# %%
from qiskit.tools.visualization import plot_histogram
result = execute(qc, simulator).result()
counts = result.get_counts(qc)
plot_histogram(counts, title='final state')

# %%
# Execute and get memory
result = execute(qc, simulator, shots=10000).result()
counts = result.get_counts(qc)
print(counts)
# Out:
# {'101': 355, '010': 2051, '001': 2165, '011': 2203, '100': 332, '110': 390, '000': 2167, '111': 337}
